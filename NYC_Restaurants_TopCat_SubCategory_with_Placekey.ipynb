# %% [markdown]
# <a href="https://colab.research.google.com/github/thilankam/Atlas_Of_Opportunity/blob/main/NYC_Restaurants_TopCat_SubCategory_with_Placekey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# combining multiple csv file by row bind
import pandas as pd
import numpy as np
import glob
import os

# %%
# Safegraph-Mobility/core_poi_after_nov2020/core_poi/2021/03/06/02

# %%
# Safegraph-Mobility/core_poi_after_nov2020/core_poi/2021/01/06/11
# contains 5 zip files
# reading core_poi data
DF_core_poi_part1 = pd.read_csv('/content/sample_data/core_poi-part1.csv')
DF_core_poi_part2 = pd.read_csv('/content/sample_data/core_poi-part2.csv')
DF_core_poi_part3 = pd.read_csv('/content/sample_data/core_poi-part3.csv')
DF_core_poi_part4 = pd.read_csv('/content/sample_data/core_poi-part4.csv')
DF_core_poi_part5 = pd.read_csv('/content/sample_data/core_poi-part5.csv')

# %% [markdown]
# Now we Fiter the 'city' column: city = 'New York City' in the each dataframe
#
# and reassign to the DF_core_poi_part1_NYC. (Now the each dataframe has only the New York City placekeys)

# %%
DF_core_poi_part1_NYC = DF_core_poi_part1.loc[DF_core_poi_part1['city'] == 'New York']
DF_core_poi_part2_NYC = DF_core_poi_part2.loc[DF_core_poi_part2['city'] == 'New York']
DF_core_poi_part3_NYC = DF_core_poi_part3.loc[DF_core_poi_part3['city'] == 'New York']
DF_core_poi_part4_NYC = DF_core_poi_part4.loc[DF_core_poi_part4['city'] == 'New York']
DF_core_poi_part5_NYC = DF_core_poi_part5.loc[DF_core_poi_part5['city'] == 'New York']

# %%
DF_core_poi_part1_NYC.head()
# Out:
#                 placekey                   safegraph_place_id parent_placekey  \
# 157  zzy-222@627-wc7-z4v  sg:0bb9f91e6071444cb3c3673f6c162775             NaN
# 313  237-222@627-s4r-rp9  sg:15c5cc00cea547a5a00d70c5d681545b             NaN
# 319  zzw-222@627-s8j-p35  sg:16073977a4ee4c7da6872ad84da7e550             NaN
# 378  zzy-222@627-wc2-33q  sg:19360c46d4ab4563b18c37a66a24c739             NaN
# 417  223-222@627-wbn-dd9  sg:1b70458768c14c8290a731860590bc0f             NaN
#
#     parent_safegraph_place_id              location_name safegraph_brand_ids  \
# 157                       NaN            Special Special                 NaN
# 313                       NaN                 Heyday UWS                 NaN
# 319                       NaN  James Kroll Citizens Bank                 NaN
# 378                       NaN        General Information                 NaN
# 417                       NaN                Gift of Gab                 NaN
#
#     brands                                       top_category  \
# 157    NaN                                        Shoe Stores
# 313    NaN                             Personal Care Services
# 319    NaN        Activities Related to Credit Intermediation
# 378    NaN  General Merchandise Stores, including Warehous...
# 417    NaN              Offices of Other Health Practitioners
#
#                                           sub_category  naics_code  ...  \
# 157                                        Shoe Stores    448210.0  ...
# 313                       Other Personal Care Services    812199.0  ...
# 319              Mortgage and Nonmortgage Loan Brokers    522310.0  ...
# 378               All Other General Merchandise Stores    452319.0  ...
# 417  Offices of Physical, Occupational and Speech T...    621340.0  ...
#
#      region  postal_code iso_country_code  phone_number  \
# 157      NY        10003               US           NaN
# 313      NY        10023               US  1.212797e+10
# 319      NY        10017               US  1.917568e+10
# 378      NY        10005               US           NaN
# 417      NY        10011               US           NaN
#
#                                             open_hours  category_tags  \
# 157                                                NaN            NaN
# 313                                                NaN            NaN
# 319  { "Mon": [["9:00", "18:00"]], "Tue": [["9:00",...            NaN
# 378                                                NaN            NaN
# 417  { "Mon": [["7:00", "21:00"]], "Tue": [["7:00",...            NaN
#
#     opened_on  closed_on tracking_opened_since tracking_closed_since
# 157       NaN        NaN                   NaN               2019-07
# 313       NaN        NaN                   NaN               2019-07
# 319       NaN        NaN                   NaN               2019-07
# 378       NaN        NaN                   NaN               2019-07
# 417       NaN        NaN                   NaN               2019-07
#
# [5 rows x 24 columns]

# %%
DF_core_poi_part1_restaurants = DF_core_poi_part1_NYC.loc[DF_core_poi_part1_NYC['top_category'] == 'Restaurants and Other Eating Places']
DF_core_poi_part2_restaurants = DF_core_poi_part2_NYC.loc[DF_core_poi_part2_NYC['top_category'] == 'Restaurants and Other Eating Places']
DF_core_poi_part3_restaurants = DF_core_poi_part3_NYC.loc[DF_core_poi_part3_NYC['top_category'] == 'Restaurants and Other Eating Places']
DF_core_poi_part4_restaurants = DF_core_poi_part4_NYC.loc[DF_core_poi_part4_NYC['top_category'] == 'Restaurants and Other Eating Places']
DF_core_poi_part5_restaurants = DF_core_poi_part5_NYC.loc[DF_core_poi_part5_NYC['top_category'] == 'Restaurants and Other Eating Places']

# %%
DF_core_poi_part1_restaurants.head()
#DF_core_poi_part5_restaurants.shape
# Out:
#                  placekey                   safegraph_place_id  \
# 823   22p-222@627-wc7-yd9  sg:379c7336ca0347bfa4bd108522168f48
# 996   23g-222@627-wc8-7h5  sg:43ccb6552cdf439f89a962234869f5d7
# 1364  224-222@627-s4t-xh5  sg:5cf324fe9fd449bfbc26986e5bb26264
# 1494  22g-222@627-s8j-9xq  sg:67684b9544024761a8292359cccb58cc
# 2395  22p-222@627-wbz-qxq  sg:a4a4d691ef3b4fd5b47fbcda9d3b79fe
#
#      parent_placekey parent_safegraph_place_id           location_name  \
# 823              NaN                       NaN              S Wan Cafe
# 996              NaN                       NaN               Starbucks
# 1364             NaN                       NaN  Las Delicias Mexicanas
# 1494             NaN                       NaN        AA Ichiban Sushi
# 2395             NaN                       NaN             Burger King
#
#                             safegraph_brand_ids       brands  \
# 823                                         NaN          NaN
# 996   SG_BRAND_f116acfe9147494063e58da666d1d57e    Starbucks
# 1364                                        NaN          NaN
# 1494                                        NaN          NaN
# 2395  SG_BRAND_60d8d6d29e2c4b14f4ea1983baefd36e  Burger King
#
#                              top_category  \
# 823   Restaurants and Other Eating Places
# 996   Restaurants and Other Eating Places
# 1364  Restaurants and Other Eating Places
# 1494  Restaurants and Other Eating Places
# 2395  Restaurants and Other Eating Places
#
#                               sub_category  naics_code  ...  region  \
# 823               Full-Service Restaurants    722511.0  ...      NY
# 996   Snack and Nonalcoholic Beverage Bars    722515.0  ...      NY
# 1364              Full-Service Restaurants    722511.0  ...      NY
# 1494           Limited-Service Restaurants    722513.0  ...      NY
# 2395           Limited-Service Restaurants    722513.0  ...      NY
#
#       postal_code iso_country_code  phone_number  \
# 823         10002               US  1.212967e+10
# 996         10014               US  1.646486e+10
# 1364        10029               US  1.212828e+10
# 1494        10011               US  1.212676e+10
# 2395        10038               US  1.212567e+10
#
#                                              open_hours  \
# 823   { "Mon": [["7:30", "18:30"]], "Tue": [["7:30",...
# 996   { "Mon": [["5:30", "20:00"]], "Tue": [["5:30",...
# 1364  { "Mon": [["8:00", "22:00"]], "Tue": [["8:00",...
# 1494                                                NaN
# 2395  { "Mon": [["6:00", "22:00"]], "Tue": [["6:00",...
#
#                                           category_tags opened_on  closed_on  \
# 823                                        Chinese Food       NaN        NaN
# 996   Snacks,Counter Service,Dessert,Tea House,Coffe...       NaN        NaN
# 1364                                       Mexican Food       NaN        NaN
# 1494                                Japanese Food,Sushi       NaN        NaN
# 2395  Counter Service,Late Night,Lunch,Fast Food,Dri...       NaN        NaN
#
#      tracking_opened_since tracking_closed_since
# 823                    NaN               2019-07
# 996                2019-12               2019-07
# 1364                   NaN               2019-07
# 1494                   NaN               2019-07
# 2395                   NaN               2019-07
#
# [5 rows x 24 columns]

# %%
DF_core_poi_part1_NYCtopCatSubCat_restaurants = DF_core_poi_part1_restaurants[['placekey','top_category', 'sub_category','city','region','street_address']]
DF_core_poi_part2_NYCtopCatSubCat_restaurants = DF_core_poi_part2_restaurants[['placekey','top_category', 'sub_category','city','region','street_address']]
DF_core_poi_part3_NYCtopCatSubCat_restaurants = DF_core_poi_part3_restaurants[['placekey','top_category', 'sub_category','city','region','street_address']]
DF_core_poi_part4_NYCtopCatSubCat_restaurants = DF_core_poi_part4_restaurants[['placekey','top_category', 'sub_category','city','region','street_address']]
DF_core_poi_part5_NYCtopCatSubCat_restaurants = DF_core_poi_part5_restaurants[['placekey','top_category', 'sub_category','city','region','street_address']]

# %%
DF_core_poi_part5_NYCtopCatSubCat_restaurants.head()
#DF_core_poi_part1_NYCtopCatSubCat_restaurants.shape
# Out:
#                  placekey                         top_category  \
# 1090  228-222@627-s8r-7yv  Restaurants and Other Eating Places
# 1652  225-223@627-wc6-yd9  Restaurants and Other Eating Places
# 1984  zzw-229@627-wc7-5j9  Restaurants and Other Eating Places
# 2177  22w-222@627-s8k-s5z  Restaurants and Other Eating Places
# 2474  zzw-222@627-s8k-xqz  Restaurants and Other Eating Places
#
#                      sub_category      city region     street_address
# 1090  Limited-Service Restaurants  New York     NY      220 W 49th St
# 1652     Full-Service Restaurants  New York     NY      519 Broome St
# 1984     Full-Service Restaurants  New York     NY  28 Mott St Frnt A
# 2177     Full-Service Restaurants  New York     NY      293 E 10th St
# 2474     Full-Service Restaurants  New York     NY       500 Grand St

# %%
NYC_RestaurentsTopCat_SubCat = pd.concat([DF_core_poi_part1_NYCtopCatSubCat_restaurants,DF_core_poi_part2_NYCtopCatSubCat_restaurants,DF_core_poi_part3_NYCtopCatSubCat_restaurants,DF_core_poi_part4_NYCtopCatSubCat_restaurants,DF_core_poi_part5_NYCtopCatSubCat_restaurants])

# %%
NYC_RestaurentsTopCat_SubCat.head(30)
NYC_RestaurentsTopCat_SubCat.shape
# Out:
# (9392, 6)
